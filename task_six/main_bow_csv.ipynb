# %%
from preprocessing.preprocessing_csv import Preprocessing_CSV_Seniority

# %%
dataset = Preprocessing_CSV_Seniority("/Users/jonas/Documents/Master_Vorlesungen/Semester_02/Practical Data Science/Final/PDS_Final/data/seniority-v2.csv")

X = dataset.X          # pd.Series of texts
y = dataset.y          # numpy array of encoded labels
y_str = dataset.y_str  # pd.Series of original labels
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dataset = Preprocessing_CSV_Seniority("/Users/jonas/Documents/Master_Vorlesungen/Semester_02/Practical Data Science/Final/PDS_Final/data/seniority-v2.csv")
#       3 X = dataset.X          # pd.Series of texts
#       4 y = dataset.y          # numpy array of encoded labels
#
# File ~/Documents/Master_Vorlesungen/Semester_02/Practical Data Science/Final/PDS_Final/task_six/preprocessing/preprocessing_csv.py:14, in Preprocessing_CSV_Seniority.__init__(self, file_path)
#      11 self.y_str = None
#      12 self.label_encoder = LabelEncoder()
# ---> 14 self.read_csv()
#
# File ~/Documents/Master_Vorlesungen/Semester_02/Practical Data Science/Final/PDS_Final/task_six/preprocessing/preprocessing_csv.py:36, in Preprocessing_CSV_Seniority.read_csv(self)
# ...

# %%
print(len(dataset))
print(dataset.get_label_mapping())
